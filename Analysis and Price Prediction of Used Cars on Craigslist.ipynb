# %%
import numpy as pd
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load dataset
vehicles_df = pd.read_csv('dataset/vehicles.csv')

# %%
vehicles_df.head()
# Out:
#            id                                                url  \
# 0  7184791621  https://duluth.craigslist.org/ctd/d/duluth-200...
# 1  7184773187  https://duluth.craigslist.org/cto/d/saginaw-20...
# 2  7193375964  https://newhaven.craigslist.org/cto/d/stratfor...
# 3  7195108810  https://albuquerque.craigslist.org/cto/d/albuq...
# 4  7184712241  https://duluth.craigslist.org/ctd/d/rush-city-...
#
#               region                          region_url  price    year  \
# 0  duluth / superior       https://duluth.craigslist.org   6995  2000.0
# 1  duluth / superior       https://duluth.craigslist.org   8750  2013.0
# 2          new haven     https://newhaven.craigslist.org  10900  2013.0
# 3        albuquerque  https://albuquerque.craigslist.org  12500  2003.0
# 4  duluth / superior       https://duluth.craigslist.org  16995  2007.0
#
#   manufacturer                  model  condition    cylinders  ... drive  \
# ...

# %%
vehicles_df.columns
# Out:
# Index(['id', 'url', 'region', 'region_url', 'price', 'year', 'manufacturer',
#        'model', 'condition', 'cylinders', 'fuel', 'odometer', 'title_status',
#        'transmission', 'vin', 'drive', 'size', 'type', 'paint_color',
#        'image_url', 'description', 'county', 'state', 'lat', 'long'],
#       dtype='object')

# %%
vehicles_df.isnull().sum()
# Out:
# id                   0
# url                  0
# region               0
# region_url           0
# price                0
# year             95114
# manufacturer    110615
# model            98473
# condition       247138
# cylinders       226178
# fuel             96643
# odometer        153272
# title_status     96098
# transmission     95792
# vin             239437
# drive           192738
# size            321230
# type            182700
# paint_color     201654
# image_url        94196
# description      94203
# county          423857
# state                0
# lat              99453
# long             99453
# dtype: int64

# %%
vehicles_df['region'].value_counts()
# Out:
# columbus               3296
# springfield            3294
# jacksonville           3284
# rochester              3087
# salem                  2985
#                        ...
# meridian                 22
# kansas city              15
# west virginia (old)      14
# st louis                  5
# fort smith, AR            1
# Name: region, Length: 404, dtype: int64

# %%
vehicles_df['title_status'].value_counts()
# Out:
# clean         315607
# rebuilt         6017
# salvage         3248
# lien            1963
# missing          711
# parts only       213
# Name: title_status, dtype: int64

# %%
vehicles_df['manufacturer'].value_counts()
# Out:
# ford               59786
# chevrolet          46603
# toyota             26001
# honda              18898
# nissan             17536
# jeep               14224
# gmc                12782
# dodge              12547
# ram                11917
# hyundai             8765
# subaru              7971
# bmw                 7717
# volkswagen          7121
# kia                 7069
# mercedes-benz       6859
# chrysler            5903
# buick               4668
# cadillac            4615
# mazda               3964
# lexus               3916
# audi                3334
# acura               2784
# lincoln             2593
# pontiac             2323
# infiniti            2318
# volvo               2097
# mitsubishi          1945
# mercury             1330
# mini                1320
# rover               1151
# saturn              1083
# jaguar               787
# fiat                 567
# tesla                299
# alfa-romeo           138
# harley-davidson      125
# datsun                69
# ...

# %%
vehicles_df['model'].value_counts()
# Out:
# f-150                          6073
# silverado 1500                 3878
# escape                         3208
# camry                          2906
# 1500                           2898
#                                ...
# Willys Jeepster                   1
# avalon limited hybrid             1
# ranger xlt xlt 4dr supercab       1
# xterra 4dr xe 4x4                 1
# fairmont wagon                    1
# Name: model, Length: 27042, dtype: int64

# %%
vehicles_df.loc[vehicles_df['manufacturer'] == 'porche']
# Out:
#                 id                                                url  \
# 136405  7194225695  https://eugene.craigslist.org/ctd/d/corvallis-...
# 220750  7181786703  https://fredericksburg.craigslist.org/cto/d/de...
# 223992  7181770466  https://annapolis.craigslist.org/cto/d/crownsv...
# 233509  7190101146  https://eugene.craigslist.org/ctd/d/corvallis-...
# 286682  7193882028  https://orangecounty.craigslist.org/ctd/d/irvi...
# 347227  7194647326  https://milwaukee.craigslist.org/cto/d/milwauk...
#
#                 region                             region_url  price    year  \
# 136405          eugene          https://eugene.craigslist.org  18995  2006.0
# 220750  fredericksburg  https://fredericksburg.craigslist.org  39499  2014.0
# 223992       annapolis       https://annapolis.craigslist.org   3700  2006.0
# 233509          eugene          https://eugene.craigslist.org  18995  2006.0
# 286682   orange county    https://orangecounty.craigslist.org  69990  2016.0
# ...

# %%
vehicles_df
# Out:
#                 id                                                url  \
# 0       7184791621  https://duluth.craigslist.org/ctd/d/duluth-200...
# 1       7184773187  https://duluth.craigslist.org/cto/d/saginaw-20...
# 2       7193375964  https://newhaven.craigslist.org/cto/d/stratfor...
# 3       7195108810  https://albuquerque.craigslist.org/cto/d/albuq...
# 4       7184712241  https://duluth.craigslist.org/ctd/d/rush-city-...
# ...            ...                                                ...
# 423852  7184919761  https://duluth.craigslist.org/cto/d/duluth-200...
# 423853  7184844576  https://duluth.craigslist.org/cto/d/duluth-200...
# 423854  7184805809  https://duluth.craigslist.org/cto/d/duluth-94-...
# 423855  7184791927  https://duluth.craigslist.org/ctd/d/duluth-199...
# 423856  7195109037  https://albuquerque.craigslist.org/ctd/d/albuq...
#
#                    region                          region_url  price    year  \
# ...

# %%
drop_columns = ['id','url','region_url','model','vin','size',
                'type','paint_color','image_url','description', 'county']

# %%
data1 = vehicles_df.drop(columns = drop_columns)

# %%
data1
# Out:
#                    region  price    year manufacturer  condition    cylinders  \
# 0       duluth / superior   6995  2000.0          gmc  excellent  8 cylinders
# 1       duluth / superior   8750  2013.0      hyundai  excellent  4 cylinders
# 2               new haven  10900  2013.0       toyota       good  4 cylinders
# 3             albuquerque  12500  2003.0   mitsubishi       good  4 cylinders
# 4       duluth / superior  16995  2007.0          gmc       good  8 cylinders
# ...                   ...    ...     ...          ...        ...          ...
# 423852  duluth / superior   1600  2006.0      hyundai       fair  6 cylinders
# 423853  duluth / superior   9000  2003.0       toyota  excellent  8 cylinders
# 423854  duluth / superior    700  1994.0         ford       fair  6 cylinders
# 423855  duluth / superior   3800  1999.0      lincoln  excellent  8 cylinders
# 423856        albuquerque   8650  2015.0       nissan        NaN          NaN
#
# ...

# %%
data1.dropna()
# Out:
#                    region  price    year manufacturer  condition    cylinders  \
# 0       duluth / superior   6995  2000.0          gmc  excellent  8 cylinders
# 1       duluth / superior   8750  2013.0      hyundai  excellent  4 cylinders
# 2               new haven  10900  2013.0       toyota       good  4 cylinders
# 4       duluth / superior  16995  2007.0          gmc       good  8 cylinders
# 5       duluth / superior  13995  2012.0         ford       good  6 cylinders
# ...                   ...    ...     ...          ...        ...          ...
# 423851        albuquerque   4800  2002.0         ford       good  6 cylinders
# 423852  duluth / superior   1600  2006.0      hyundai       fair  6 cylinders
# 423853  duluth / superior   9000  2003.0       toyota  excellent  8 cylinders
# 423854  duluth / superior    700  1994.0         ford       fair  6 cylinders
# 423855  duluth / superior   3800  1999.0      lincoln  excellent  8 cylinders
#
# ...
