# %%
import numpy as pd
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load dataset
vehicles_df = pd.read_csv('dataset/vehicles.csv')

# %%
vehicles_df.head()
# Out:
#            id                                                url  \
# 0  7184791621  https://duluth.craigslist.org/ctd/d/duluth-200...
# 1  7184773187  https://duluth.craigslist.org/cto/d/saginaw-20...
# 2  7193375964  https://newhaven.craigslist.org/cto/d/stratfor...
# 3  7195108810  https://albuquerque.craigslist.org/cto/d/albuq...
# 4  7184712241  https://duluth.craigslist.org/ctd/d/rush-city-...
#
#               region                          region_url  price    year  \
# 0  duluth / superior       https://duluth.craigslist.org   6995  2000.0
# 1  duluth / superior       https://duluth.craigslist.org   8750  2013.0
# 2          new haven     https://newhaven.craigslist.org  10900  2013.0
# 3        albuquerque  https://albuquerque.craigslist.org  12500  2003.0
# 4  duluth / superior       https://duluth.craigslist.org  16995  2007.0
#
#   manufacturer                  model  condition    cylinders  ... drive  \
# ...

# %%
vehicles_df.columns
# Out:
# Index(['id', 'url', 'region', 'region_url', 'price', 'year', 'manufacturer',
#        'model', 'condition', 'cylinders', 'fuel', 'odometer', 'title_status',
#        'transmission', 'vin', 'drive', 'size', 'type', 'paint_color',
#        'image_url', 'description', 'county', 'state', 'lat', 'long'],
#       dtype='object')

# %%
vehicles_df.isnull().sum()
# Out:
# id                   0
# url                  0
# region               0
# region_url           0
# price                0
# year             95114
# manufacturer    110615
# model            98473
# condition       247138
# cylinders       226178
# fuel             96643
# odometer        153272
# title_status     96098
# transmission     95792
# vin             239437
# drive           192738
# size            321230
# type            182700
# paint_color     201654
# image_url        94196
# description      94203
# county          423857
# state                0
# lat              99453
# long             99453
# dtype: int64

# %%
vehicles_df['title_status'].unique()
# Out:
# array(['clean', 'lien', 'rebuilt', 'salvage', 'missing', 'parts only',
#        nan], dtype=object)

# %%
vehicles_df.groupby('manufacturer')['id'].count()
# Out:
# manufacturer
# acura               2784
# alfa-romeo           138
# aston-martin          28
# audi                3334
# bmw                 7717
# buick               4668
# cadillac            4615
# chevrolet          46603
# chrysler            5903
# datsun                69
# dodge              12547
# ferrari               64
# fiat                 567
# ford               59786
# gmc                12782
# harley-davidson      125
# hennessey              1
# honda              18898
# hyundai             8765
# infiniti            2318
# jaguar               787
# jeep               14224
# kia                 7069
# land rover            15
# lexus               3916
# lincoln             2593
# mazda               3964
# mercedes-benz       6859
# mercury             1330
# mini                1320
# mitsubishi          1945
# morgan                 3
# nissan             17536
# pontiac             2323
# porche                 6
# ram                11917
# ...

# %%
vehicles_df['model'].unique()
# Out:
# array(['new sierra 1500', 'sonata', 'prius', ..., '1990 F350',
#        'ranchero gt cobra', 'Studebaker GT Hawk Torisimo'], dtype=object)

# %%
len(vehicles_df['model'].unique())
# Out:
# 27043

# %%
vehicles_df.loc[vehicles_df['manufacturer'] == 'porche']
# Out:
#                 id                                                url  \
# 136405  7194225695  https://eugene.craigslist.org/ctd/d/corvallis-...
# 220750  7181786703  https://fredericksburg.craigslist.org/cto/d/de...
# 223992  7181770466  https://annapolis.craigslist.org/cto/d/crownsv...
# 233509  7190101146  https://eugene.craigslist.org/ctd/d/corvallis-...
# 286682  7193882028  https://orangecounty.craigslist.org/ctd/d/irvi...
# 347227  7194647326  https://milwaukee.craigslist.org/cto/d/milwauk...
#
#                 region                             region_url  price    year  \
# 136405          eugene          https://eugene.craigslist.org  18995  2006.0
# 220750  fredericksburg  https://fredericksburg.craigslist.org  39499  2014.0
# 223992       annapolis       https://annapolis.craigslist.org   3700  2006.0
# 233509          eugene          https://eugene.craigslist.org  18995  2006.0
# 286682   orange county    https://orangecounty.craigslist.org  69990  2016.0
# ...
